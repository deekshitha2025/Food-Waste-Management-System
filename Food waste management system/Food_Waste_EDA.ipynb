# %%
print("Hello")
# Out:
# Hello

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "mysql+pymysql://root:Deekshu%4013@localhost/food_waste"
)

# %%
providers = pd.read_sql("SELECT * FROM providers", engine)
receivers = pd.read_sql("SELECT * FROM receivers", engine)
food = pd.read_sql("SELECT * FROM food_listings", engine)
claims = pd.read_sql("SELECT * FROM claims", engine)

print(providers.shape)
print(receivers.shape)
print(food.shape)
print(claims.shape)
# Out:
# (1000, 6)
# (1000, 5)
# (1000, 9)
# (1000, 5)

# %%
providers.head()
# Out:
#    Provider_ID                         Name           Type  \
# 0            1             Gonzales-Cochran    Supermarket
# 1            2  Nielsen, Johnson and Fuller  Grocery Store
# 2            3                 Miller-Black    Supermarket
# 3            4   Clark, Prince and Williams  Grocery Store
# 4            5               Coleman-Farley  Grocery Store
#
#                                              Address            City  \
# 0  74347 Christopher Extensions\nAndreamouth, OK ...     New Jessica
# 1           91228 Hanson Stream\nWelchtown, OR 27136     East Sheena
# 2  561 Martinez Point Suite 507\nGuzmanchester, W...  Lake Jesusview
# 3     467 Bell Trail Suite 409\nPort Jesus, IA 61188     Mendezmouth
# 4  078 Matthew Creek Apt. 319\nSaraborough, MA 53978   Valentineside
#
#                 Contact
# 0       +1-600-220-0480
# 1  +1-925-283-8901x6297
# 2      001-517-295-2206
# 3      556.944.8935x401
# 4          193.714.6577

# %%
print(providers.shape)
print(receivers.shape)
print(food.shape)
print(claims.shape)
# Out:
# (1000, 6)
# (1000, 5)
# (1000, 9)
# (1000, 5)

# %%
food.groupby('Location')['Quantity'].sum().sort_values(ascending=False).head(10)
# Out:
# Location
# South Kathryn               179
# Jonathanstad                169
# New Carol                   167
# North Keith                 158
# Jimmyberg                   150
# Lake Andrewmouth            142
# Lake Travis                 140
# South Christopherborough    137
# Port Patrick                127
# Perezport                   123
# Name: Quantity, dtype: int64

# %%
food.groupby('Provider_ID')['Quantity'].sum().sort_values(ascending=False).head(10)
# Out:
# Provider_ID
# 709    179
# 306    158
# 655    150
# 315    142
# 678    140
# 499    124
# 41     123
# 161    123
# 262    121
# 146    116
# Name: Quantity, dtype: int64

# %%
claims['Receiver_ID'].value_counts().head(10)
# Out:
# Receiver_ID
# 371    5
# 276    5
# 800    5
# 742    5
# 493    4
# 90     4
# 324    4
# 901    4
# 301    4
# 144    4
# Name: count, dtype: int64

# %%
claims['Status'].value_counts(normalize=True)*100
# Out:
# Status
# Completed    33.9
# Cancelled    33.6
# Pending      32.5
# Name: proportion, dtype: float64

# %%
claims.merge(
    receivers,
    on='Receiver_ID'
).groupby('City').size().sort_values(ascending=False).head(10)
# Out:
# City
# Brownbury       5
# Emilymouth      5
# West David      5
# Smithshire      5
# Greenton        5
# Port Dean       5
# Port Richard    5
# Markfurt        4
# North Paul      4
# Spencermouth    4
# dtype: int64

# %%
food['Food_Type'].value_counts()
# Out:
# Food_Type
# Vegetarian        336
# Vegan             334
# Non-Vegetarian    330
# Name: count, dtype: int64

# %%
claims.merge(
    food,
    on='Food_ID'
)['Meal_Type'].value_counts()
# Out:
# Meal_Type
# Breakfast    278
# Lunch        250
# Snacks       240
# Dinner       232
# Name: count, dtype: int64

# %%
food['Quantity'].sum()
# Out:
# np.int64(25794)

# %%
food.groupby('Provider_ID')['Quantity'].sum().sort_values(ascending=False).head(10)
# Out:
# Provider_ID
# 709    179
# 306    158
# 655    150
# 315    142
# 678    140
# 499    124
# 41     123
# 161    123
# 262    121
# 146    116
# Name: Quantity, dtype: int64

# %%
claims['Receiver_ID'].value_counts().head(10)
# Out:
# Receiver_ID
# 371    5
# 276    5
# 800    5
# 742    5
# 493    4
# 90     4
# 324    4
# 901    4
# 301    4
# 144    4
# Name: count, dtype: int64

# %%
providers['City'].value_counts().head(10)
# Out:
# City
# New Carol                   3
# South Christopherborough    3
# New Amanda                  2
# North Kevinhaven            2
# Lake Kyle                   2
# North Michelle              2
# West Lauraborough           2
# New Richard                 2
# East Melissa                2
# New Daniel                  2
# Name: count, dtype: int64

# %%
providers['Type'].value_counts()
# Out:
# Type
# Supermarket         262
# Grocery Store       256
# Restaurant          246
# Catering Service    236
# Name: count, dtype: int64

# %%
food.groupby('Provider_ID')['Quantity'].sum().sort_values(ascending=False).head(10)
# Out:
# Provider_ID
# 709    179
# 306    158
# 655    150
# 315    142
# 678    140
# 499    124
# 41     123
# 161    123
# 262    121
# 146    116
# Name: Quantity, dtype: int64

# %%
receivers['City'].value_counts().head(10)
# Out:
# City
# New Christopher    3
# Spencermouth       2
# Moorechester       2
# Lake Mary          2
# Smithshire         2
# Lake Daniel        2
# Kellybury          2
# Greenton           2
# North Lori         2
# West James         2
# Name: count, dtype: int64

# %%
receivers['Type'].value_counts()
# Out:
# Type
# NGO           274
# Charity       263
# Shelter       246
# Individual    217
# Name: count, dtype: int64

# %%
claims['Receiver_ID'].value_counts().head(10)
# Out:
# Receiver_ID
# 371    5
# 276    5
# 800    5
# 742    5
# 493    4
# 90     4
# 324    4
# 901    4
# 301    4
# 144    4
# Name: count, dtype: int64

# %%
food.groupby('Food_Type')['Quantity'].sum().sort_values(ascending=False)
# Out:
# Food_Type
# Vegan             8798
# Non-Vegetarian    8656
# Vegetarian        8340
# Name: Quantity, dtype: int64

# %%
food.groupby('Meal_Type')['Quantity'].sum().sort_values(ascending=False)
# Out:
# Meal_Type
# Snacks       6693
# Breakfast    6667
# Lunch        6373
# Dinner       6061
# Name: Quantity, dtype: int64

# %%
food['Quantity'].mean()
# Out:
# np.float64(25.794)

# %%
claims['Status'].value_counts()
# Out:
# Status
# Completed    339
# Cancelled    336
# Pending      325
# Name: count, dtype: int64

# %%
(claims['Status'].value_counts(normalize=True)*100).round(2)
# Out:
# Status
# Completed    33.9
# Cancelled    33.6
# Pending      32.5
# Name: proportion, dtype: float64

# %%
claims[claims['Status']=='Completed'].shape[0]
# Out:
# 339

# %%
claims.merge(receivers,on='Receiver_ID')['City'].value_counts().head(10)
# Out:
# City
# Port Dean           5
# Port Richard        5
# Greenton            5
# Brownbury           5
# Emilymouth          5
# Smithshire          5
# West David          5
# Lake Rachelburgh    4
# Spencermouth        4
# Kellybury           4
# Name: count, dtype: int64
